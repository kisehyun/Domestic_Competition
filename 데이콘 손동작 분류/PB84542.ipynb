# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

from catboost import CatBoostClassifier, Pool
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
from lightgbm import LGBMClassifier

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
X = train.iloc[:, 1:-1]
y = train.target
target = test.iloc[:, 1:]

# %%
skf = StratifiedKFold(n_splits = 10, random_state = 42, shuffle = True)

# %%
cb_acc = []
cb_pred = np.zeros((target.shape[0], 4))
for i, (tr_idx, val_idx) in enumerate(skf.split(X, y)) :
    print(f'{i + 1} Fold Training.....')
    tr_x, tr_y = X.iloc[tr_idx], y.iloc[tr_idx]
    val_x, val_y = X.iloc[val_idx], y.iloc[val_idx]
    
    tr_data = Pool(data = tr_x, label = tr_y)
    val_data = Pool(data = val_x, label = val_y)
    
    cb = CatBoostClassifier(random_state = 42, n_estimators = 1500, learning_rate = 0.03, max_depth = 5, use_best_model = True, loss_function = 'MultiClass')
    cb.fit(tr_data, eval_set = val_data, early_stopping_rounds = 250, verbose = 250)
    val_pred = cb.predict_proba(val_data)
    val_cls = np.argmax(val_pred, axis = 1)
    fold_val_acc = accuracy_score(val_y, val_cls)
    cb_acc.append(fold_val_acc)
    print(f'{i + 1} Fold ACCURACY of Validation = {fold_val_acc}\n')
    
    fold_pred = cb.predict_proba(target) / skf.n_splits
    cb_pred += fold_pred
print(np.mean(cb_acc))
# Out:
# 1 Fold Training.....
# 0:	learn: 1.3756879	test: 1.3768443	best: 1.3768443 (0)	total: 10.3ms	remaining: 15.4s
# 250:	learn: 0.6716020	test: 0.7741736	best: 0.7741736 (250)	total: 726ms	remaining: 3.61s
# 500:	learn: 0.4368695	test: 0.5951924	best: 0.5951924 (500)	total: 1.52s	remaining: 3.04s
# 750:	learn: 0.3168457	test: 0.5275679	best: 0.5275679 (750)	total: 2.24s	remaining: 2.24s
# 1000:	learn: 0.2439541	test: 0.4909851	best: 0.4906415 (995)	total: 3.02s	remaining: 1.51s
# 1250:	learn: 0.1927972	test: 0.4738375	best: 0.4738375 (1250)	total: 3.74s	remaining: 744ms
# 1499:	learn: 0.1570263	test: 0.4605899	best: 0.4603414 (1497)	total: 4.53s	remaining: 0us
#
# bestTest = 0.4603413614
# bestIteration = 1497
#
# Shrink model to first 1498 iterations.
# 1 Fold ACCURACY of Validation = 0.8418803418803419
#
# 2 Fold Training.....
# 0:	learn: 1.3766256	test: 1.3762224	best: 1.3762224 (0)	total: 7.46ms	remaining: 11.2s
# 250:	learn: 0.6621034	test: 0.7858659	best: 0.7858659 (250)	total: 769ms	remaining: 3.83s
# 500:	learn: 0.4299881	test: 0.6262885	best: 0.6262885 (500)	total: 1.48s	remaining: 2.95s
# 750:	learn: 0.3142664	test: 0.5614568	best: 0.5613086 (747)	total: 2.19s	remaining: 2.19s
# 1000:	learn: 0.2421426	test: 0.5260632	best: 0.5260632 (1000)	total: 2.91s	remaining: 1.45s
# 1250:	learn: 0.1920932	test: 0.4998349	best: 0.4997834 (1247)	total: 3.62s	remaining: 721ms
# 1499:	learn: 0.1564554	test: 0.4869768	best: 0.4866630 (1490)	total: 4.33s	remaining: 0us
#
# bestTest = 0.486662967
# bestIteration = 1490
#
# Shrink model to first 1491 iterations.
# 2 Fold ACCURACY of Validation = 0.8290598290598291
#
# 3 Fold Training.....
# 0:	learn: 1.3755591	test: 1.3779705	best: 1.3779705 (0)	total: 5.64ms	remaining: 8.45s
# 250:	learn: 0.6701366	test: 0.7611716	best: 0.7611716 (250)	total: 724ms	remaining: 3.6s
# 500:	learn: 0.4376868	test: 0.5789056	best: 0.5789056 (500)	total: 1.43s	remaining: 2.85s
# 750:	learn: 0.3181953	test: 0.5020261	best: 0.5020261 (750)	total: 2.13s	remaining: 2.13s
# 1000:	learn: 0.2448598	test: 0.4641084	best: 0.4641084 (1000)	total: 2.83s	remaining: 1.41s
# 1250:	learn: 0.1957348	test: 0.4378745	best: 0.4378745 (1250)	total: 3.54s	remaining: 705ms
# 1499:	learn: 0.1597356	test: 0.4192541	best: 0.4192450 (1498)	total: 4.24s	remaining: 0us
#
# bestTest = 0.4192450453
# bestIteration = 1498
#
# Shrink model to first 1499 iterations.
# 3 Fold ACCURACY of Validation = 0.8632478632478633
#
# 4 Fold Training.....
# 0:	learn: 1.3767007	test: 1.3772819	best: 1.3772819 (0)	total: 5.53ms	remaining: 8.29s
# 250:	learn: 0.6708478	test: 0.7520123	best: 0.7520123 (250)	total: 716ms	remaining: 3.56s
# 500:	learn: 0.4391370	test: 0.5766521	best: 0.5766521 (500)	total: 1.42s	remaining: 2.82s
# 750:	learn: 0.3216310	test: 0.5016775	best: 0.5016775 (750)	total: 2.12s	remaining: 2.11s
# 1000:	learn: 0.2468107	test: 0.4630684	best: 0.4630684 (1000)	total: 2.82s	remaining: 1.4s
# 1250:	learn: 0.1965398	test: 0.4372114	best: 0.4372114 (1250)	total: 3.53s	remaining: 703ms
# 1499:	learn: 0.1607662	test: 0.4224808	best: 0.4224808 (1499)	total: 4.23s	remaining: 0us
#
# bestTest = 0.4224807648
# bestIteration = 1499
#
# 4 Fold ACCURACY of Validation = 0.8632478632478633
#
# 5 Fold Training.....
# 0:	learn: 1.3758941	test: 1.3770770	best: 1.3770770 (0)	total: 5.43ms	remaining: 8.14s
# 250:	learn: 0.6641653	test: 0.8072447	best: 0.8072447 (250)	total: 701ms	remaining: 3.49s
# 500:	learn: 0.4341332	test: 0.6399449	best: 0.6399449 (500)	total: 1.42s	remaining: 2.83s
# 750:	learn: 0.3152713	test: 0.5630060	best: 0.5629467 (749)	total: 2.12s	remaining: 2.12s
# 1000:	learn: 0.2403174	test: 0.5263648	best: 0.5261108 (999)	total: 2.85s	remaining: 1.42s
# 1250:	learn: 0.1922333	test: 0.5038627	best: 0.5038217 (1248)	total: 3.57s	remaining: 711ms
# 1499:	learn: 0.1572779	test: 0.4856269	best: 0.4854644 (1498)	total: 4.3s	remaining: 0us
#
# bestTest = 0.4854644112
# bestIteration = 1498
#
# Shrink model to first 1499 iterations.
# 5 Fold ACCURACY of Validation = 0.8461538461538461
#
# 6 Fold Training.....
# 0:	learn: 1.3750156	test: 1.3749829	best: 1.3749829 (0)	total: 5.39ms	remaining: 8.08s
# 250:	learn: 0.6648990	test: 0.7611975	best: 0.7611975 (250)	total: 706ms	remaining: 3.51s
# 500:	learn: 0.4339111	test: 0.5960094	best: 0.5960094 (500)	total: 1.41s	remaining: 2.8s
# 750:	learn: 0.3177762	test: 0.5339791	best: 0.5339791 (750)	total: 2.11s	remaining: 2.11s
# 1000:	learn: 0.2459344	test: 0.5029223	best: 0.5029223 (1000)	total: 2.82s	remaining: 1.4s
# 1250:	learn: 0.1967393	test: 0.4876597	best: 0.4876360 (1246)	total: 3.52s	remaining: 701ms
# 1499:	learn: 0.1593354	test: 0.4794414	best: 0.4791564 (1491)	total: 4.22s	remaining: 0us
#
# bestTest = 0.4791564057
# bestIteration = 1491
#
# Shrink model to first 1492 iterations.
# 6 Fold ACCURACY of Validation = 0.8154506437768241
#
# 7 Fold Training.....
# 0:	learn: 1.3755882	test: 1.3767887	best: 1.3767887 (0)	total: 5.76ms	remaining: 8.64s
# 250:	learn: 0.6653117	test: 0.7725917	best: 0.7725917 (250)	total: 712ms	remaining: 3.54s
# 500:	learn: 0.4339598	test: 0.6161191	best: 0.6161191 (500)	total: 1.41s	remaining: 2.82s
# 750:	learn: 0.3132354	test: 0.5520675	best: 0.5519567 (749)	total: 2.11s	remaining: 2.11s
# 1000:	learn: 0.2389902	test: 0.5186315	best: 0.5186315 (1000)	total: 2.81s	remaining: 1.4s
# 1250:	learn: 0.1909264	test: 0.4989024	best: 0.4989024 (1250)	total: 3.51s	remaining: 699ms
# 1499:	learn: 0.1554347	test: 0.4869700	best: 0.4869700 (1499)	total: 4.21s	remaining: 0us
#
# bestTest = 0.4869699725
# bestIteration = 1499
#
# 7 Fold ACCURACY of Validation = 0.8454935622317596
#
# 8 Fold Training.....
# 0:	learn: 1.3758656	test: 1.3765197	best: 1.3765197 (0)	total: 5.53ms	remaining: 8.29s
# 250:	learn: 0.6660276	test: 0.8073889	best: 0.8073889 (250)	total: 700ms	remaining: 3.48s
# 500:	learn: 0.4285777	test: 0.6446140	best: 0.6446140 (500)	total: 1.41s	remaining: 2.81s
# 750:	learn: 0.3113395	test: 0.5790585	best: 0.5790585 (750)	total: 2.16s	remaining: 2.15s
# 1000:	learn: 0.2406733	test: 0.5484726	best: 0.5484726 (1000)	total: 2.88s	remaining: 1.43s
# 1250:	learn: 0.1912107	test: 0.5276002	best: 0.5276002 (1250)	total: 3.6s	remaining: 716ms
# 1499:	learn: 0.1558680	test: 0.5167823	best: 0.5166558 (1493)	total: 4.32s	remaining: 0us
#
# bestTest = 0.5166558169
# bestIteration = 1493
#
# Shrink model to first 1494 iterations.
# 8 Fold ACCURACY of Validation = 0.8369098712446352
#
# 9 Fold Training.....
# 0:	learn: 1.3770853	test: 1.3772317	best: 1.3772317 (0)	total: 6.17ms	remaining: 9.24s
# 250:	learn: 0.6681007	test: 0.7711805	best: 0.7711805 (250)	total: 704ms	remaining: 3.5s
# 500:	learn: 0.4376724	test: 0.6071355	best: 0.6071355 (500)	total: 1.42s	remaining: 2.83s
# 750:	learn: 0.3191582	test: 0.5357873	best: 0.5357873 (750)	total: 2.16s	remaining: 2.16s
# 1000:	learn: 0.2449492	test: 0.4982839	best: 0.4982839 (1000)	total: 2.87s	remaining: 1.43s
# 1250:	learn: 0.1971201	test: 0.4796414	best: 0.4794108 (1245)	total: 3.59s	remaining: 714ms
# 1499:	learn: 0.1612251	test: 0.4674006	best: 0.4674006 (1499)	total: 4.38s	remaining: 0us
#
# bestTest = 0.4674005943
# bestIteration = 1499
#
# 9 Fold ACCURACY of Validation = 0.8240343347639485
#
# 10 Fold Training.....
# 0:	learn: 1.3768193	test: 1.3756394	best: 1.3756394 (0)	total: 7.43ms	remaining: 11.1s
# 250:	learn: 0.6752402	test: 0.7379253	best: 0.7379253 (250)	total: 742ms	remaining: 3.69s
# 500:	learn: 0.4411141	test: 0.5550941	best: 0.5550941 (500)	total: 1.52s	remaining: 3.02s
# 750:	learn: 0.3208700	test: 0.4801710	best: 0.4801710 (750)	total: 2.24s	remaining: 2.24s
# 1000:	learn: 0.2448064	test: 0.4437988	best: 0.4437988 (1000)	total: 3.01s	remaining: 1.5s
# 1250:	learn: 0.1945012	test: 0.4183767	best: 0.4183767 (1250)	total: 3.76s	remaining: 749ms
# 1499:	learn: 0.1597843	test: 0.4050804	best: 0.4047678 (1492)	total: 4.51s	remaining: 0us
#
# bestTest = 0.404767805
# bestIteration = 1492
#
# Shrink model to first 1493 iterations.
# 10 Fold ACCURACY of Validation = 0.8755364806866953
#
# 0.8441014636293607

# %%
submission['target'] = np.argmax(cb_pred, axis = 1)

# %%
submission.to_csv('1st.csv', index = False)

# %%
submission.target.value_counts()
# Out:
# 2    2524
# 1    2495
# 0    2227
# 3    2097
# Name: target, dtype: int64
